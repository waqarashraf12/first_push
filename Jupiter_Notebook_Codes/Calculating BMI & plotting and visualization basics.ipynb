# %% [markdown]
# ## Procedure for calculating Body mass index (BMI)
# 1-using input fcn
# 2-ask your height in one variable
# 3-then weight
# 4-calculate the BMI
# 5-print it
# 6-My name is ...., and my BMI is ....,

# %%
weight = input("weight is: ")
# Out:
# weight is: 55

# %%
height = input("height is: ")
height = float(height)
# Out:
# height is: 1.67

# %%
weight = input("weight is: ")
weight = float(weight)
# Out:
# weight is: 56

# %%
name = input("My name is: ")
# Out:
# My name is: Waqar

# %%
BMI = weight/height**2
BMI
print("My name is", name, "and my BMI is,", BMI)
# Out:
# My name is Waqar and my BMI is, 20.07960127648894

# %% [markdown]
# ## Visualization and plot
# **using matplotlib and seaborn libraries for this**

# %%
import seaborn as sns
import matplotlib as plt
sns.set_theme(style = "ticks", color_codes = True)
titanic = sns.load_dataset('titanic')
sns.catplot(x = 'sex', y = 'survived', hue = 'class', kind = 'bar',data = titanic)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 6
#       4 titanic = sns.load_dataset('titanic')
#       5 sns.catplot(x = 'sex', y = 'survived', hue = 'class', kind = 'bar',data = titanic)
# ----> 6 plt.show()
#
# File ~\OneDrive\Documents\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
import seaborn as sns
import matplotlib as plt
sns.set_theme(style = "ticks", color_codes = True)
titanic = sns.load_dataset('titanic')
p1 = sns.countplot(x = 'sex', data = titanic, hue = 'class') 
p1.set_title('plot for counting')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 7
#       5 p1 = sns.countplot(x = 'sex', data = titanic, hue = 'class')
#       6 p1.set_title('plot for counting')
# ----> 7 plt.show()
#
# File ~\OneDrive\Documents\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
import seaborn as sns
import matplotlib as plt
sns.set_theme(style = "ticks", color_codes = True)
titanic = sns.load_dataset('titanic')
g = sns.FacetGrid(titanic, row = 'sex', hue = 'alone')
g = (g.map(plt.scatter, 'age', 'fare').add_legend())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 6
#       4 titanic = sns.load_dataset('titanic')
#       5 g = sns.FacetGrid(titanic, row = 'sex', hue = 'alone')
# ----> 6 g = (g.map(plt.scatter, 'age', 'fare').add_legend())
#       7 plt.show()
#
# File ~\OneDrive\Documents\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'scatter'
